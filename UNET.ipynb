# %% [markdown]
# <a href="https://colab.research.google.com/github/raj005-gitH/AI-ML-Google-Collab/blob/main/UNET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install kaggle

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
! mkdir ~/.kaggle

# %%
! cp /content/kaggle.json ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat '/content/kaggle.json': No such file or directory

# %%
! kaggle datasets download -d paultimothymooney/predict-diabetes-from-medical-records
# Out:
# 403 Client Error: Forbidden for url: https://api.kaggle.com/v1/datasets.DatasetApiService/GetDatasetMetadata
